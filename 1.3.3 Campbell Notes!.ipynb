# %%
Would want python to automate the algrithm to human population
help, return, def
You make your own code in Ipython sessions (or in our case jupyter sessions)
You don't have to type as much
# Out:
#   File "<ipython-input-1-d0e115c6fbba>", line 1
#     Would want python to automate the algrithm to human population
#              ^
# SyntaxError: invalid syntax

# %%
Or: If either condition is meet is true. If both are meet is false
    if x>5 or x<10:
        print ("True")
    if x==7 or x<10
        print ("True")
# Out:
#   File "<ipython-input-2-cef50f528dd0>", line 1
#     Or: If either condition is meet is true. If both are meet is false
#                 ^
# SyntaxError: invalid syntax

# %%
Not: The opossite of the condition is true
    if a>5 not X<10:
        print ("True")
# Out:
#   File "<ipython-input-3-bf16fb4acdf0>", line 1
#     Not: The opossite of the condition is true
#                     ^
# SyntaxError: invalid syntax

# %%
and: both conitions must be true to execture.
    if x>5 and X<10
        print ("True")
# Out:
#   File "<ipython-input-4-3684e4d9b4f4>", line 1
#     and: both conitions must be true to execture.
#       ^
# SyntaxError: invalid syntax

# %%
Activity Book Notes

3: It will mesure out as true, due to it having the ability to match the criteria
# Out:
#   File "<ipython-input-1-c9543125dffa>", line 1
#     Activity Book Notes
#                 ^
# SyntaxError: invalid syntax

# %%
a=3
a**2 >= 9 and not a>3

a+2 == 5 or a-1 != 3
# Out:
# True

# %%
x, y = (65, 40)
print: ("x")
    
50 < x and x < 80 and 30 <= y and y <= 45
True
    
#another conditional
x == 70, and y == 40
False
# Out:
#   File "<ipython-input-14-77c88df4df35>", line 8
#     x == 70, and y == 40
#                ^
# SyntaxError: invalid syntax

# %%
4: the one above this is 4
the one bellow this is 5
# Out:
#   File "<ipython-input-15-b102fd5e59d0>", line 1
#     4: the one above this is 4
#              ^
# SyntaxError: invalid syntax

# %%
x, y = (90, 1115)
print ("x")
    
50 < x and x < 80 and 30 <= y and y <= 45
True
    
#another conditional
x == 70, and y == 40
False
# Out:
#   File "<ipython-input-16-abf55205583a>", line 8
#     x == 70, and y == 40
#                ^
# SyntaxError: invalid syntax

# %%
6:
# Out:
#   File "<ipython-input-17-23265b6b0143>", line 1
#     6:
#       ^
# SyntaxError: invalid syntax

# %%
from __future__ import print_function # use Python 3.0 printing

def age_limit_output(age):
    age==18
AGE_LIMIT = 13  
if age < AGE_LIMIT:
      print (age, 'is below the age limit.')
else:
      print(age, 'is old enough.')
print(' Minimum age is ', AGE_LIMIT)
# Out:
# 12 is below the age limit.
#  Minimum age is  13

# %%
def age_limit_output(age): 
    age==10
AGE_LIMIT = 13  
if age < AGE_LIMIT:
      print (age, 'is below the age limit.')
else:
      print(age, 'is old enough.')
print(' Minimum age is ', AGE_LIMIT)
# Out:
# 12 is below the age limit.
#  Minimum age is  13

# %%
def age_limit_output(age):
    age==16
AGE_LIMIT = 13  
if age < AGE_LIMIT:
      print (age, 'is below the age limit.')
else:
      print(age, 'is old enough.')
print(' Minimum age is ', AGE_LIMIT)
# Out:
# 12 is below the age limit.
#  Minimum age is  13

# %%
9:
# Out:
#   File "<ipython-input-45-cf4b9af9ed57>", line 1
#     9:
#       ^
# SyntaxError: invalid syntax

# %%
secret = ['red','red','yellow','yellow','black']
def hint():
    hint('red', secret)
print ("The color red IS in the secret sequence of colors.")
# Out:
# The color red IS in the secret sequence of colors.

# %%
def hint():  
    hint(green, secret)
print ("The color green IS NOT in the secret sequence of colors")
# Out:
# The color green IS NOT in the secret sequence of colors
